# %% [markdown]
# # **Entrenamiento y evaluación de un sistema de edición de luz basado en perceptrón multicapa**
#
# _________________________________________________________________________________________________________________________________________________________________________________________________________
# Angel Toledo Flores<br>
# Ingeniero Mecánico Agrícola/Ingeniero en Sistemas Computacionales.<br>
# **E-mail**: contactoangeltoledo@gmail.com<br>
#  [Linkedin profile](https://www.linkedin.com/in/angel-toledo/) | [Portafolio de proyectos](https://resume.ingesaurio.com) <br>
#  [ DataSet: kagle](https://www.kaggle.com/code/shruthimshruthim/google-scrapped-image)

# %%
import cv2 
import matplotlib.pyplot as plt
import random
import numpy as np

# %% [markdown]
# # ImportData

# %% [markdown]
# ## Google

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mkdir /content/image_input

# %%
# !cp -R /content/gdrive/MyDrive/Automatic_light_editing/image_input/* /content/image_input

# %% [markdown]
# # Setings

# %%
import glob
import cv2 
import matplotlib.pyplot as plt
import random
import numpy as np

def splitDataset(PATH = '/content/image_input/*', test = 0.3):
  train_d = []
  test_d = glob.glob(PATH)
  for i in range(int(len(test_d)*test)):
    random_img = random.choice(test_d)
    train_d.append(random_img)
    test_d.remove(random_img)
  return train_d, test_d

def read_img(PATH):
  """
  Read img and transform to HSV
  """
  img = cv2.imread(PATH)
  img = cv2.resize(img,(128,128))
  hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV) / 255.0
  return hsv

def gen_data(hsv):
  """ 
  Edit ligth in the value V in RSV
  """
  d_sigma = (0.1 * random.choice([i for i in range(3,17) if i not in [9,10,11]]) )
  v =  hsv[:,:,2] * d_sigma
  v = np.array(v)
  return [v.flatten(),d_sigma]

def create_dataSet(path_list, n=7):
  """
  Create 3 new img whit diferent light values for img
  """
  x_t = []
  y_t = []
  HSV_ARRAY = []
  for element in path_list:
    hsv = read_img(element)
    for i in range(n):
        x,y = gen_data(hsv)
        x_t.append(x)
        y_t.append(y) 
        HSV_ARRAY.append(hsv)
  return x_t, y_t, HSV_ARRAY

# %% [markdown]
# # Train

# %%
import glob
#path_list = glob.glob('/content/image_input/*')
train_list, test_list = splitDataset()
x_train, y_train, HSV_TRAIN = create_dataSet(train_list)
x_test, y_test, HSV_TEST = create_dataSet(test_list)

x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
import tensorflow as tf

seed = 7
numpy.random.seed(seed)
model = Sequential()
model.add(Dense(12, input_dim=16384, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='linear'))
losse = tf.keras.losses.MeanAbsoluteError()

model.compile(loss=losse, optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1921 - accuracy: 0.0000e+00
# Epoch 2/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.1586 - accuracy: 0.0000e+00
# Epoch 3/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.1559 - accuracy: 0.0000e+00
# Epoch 4/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.1518 - accuracy: 0.0000e+00
# Epoch 5/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.1487 - accuracy: 0.0000e+00
# Epoch 6/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.1453 - accuracy: 0.0000e+00
# Epoch 7/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1408 - accuracy: 0.0000e+00
# Epoch 8/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1334 - accuracy: 0.0000e+00
# Epoch 9/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1368 - accuracy: 0.0000e+00
# Epoch 10/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1255 - accuracy: 0.0000e+00
# Epoch 11/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1299 - accuracy: 0.0000e+00
# Epoch 12/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1201 - accuracy: 0.0000e+00
# Epoch 13/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1145 - accuracy: 0.0000e+00
# Epoch 14/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1130 - accuracy: 0.0000e+00
# Epoch 15/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1111 - accuracy: 0.0000e+00
# Epoch 16/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1061 - accuracy: 0.0000e+00
# Epoch 17/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.1023 - accuracy: 0.0000e+00
# Epoch 18/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0990 - accuracy: 0.0000e+00
# Epoch 19/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0986 - accuracy: 0.0000e+00
# Epoch 20/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0958 - accuracy: 0.0000e+00
# Epoch 21/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0916 - accuracy: 0.0000e+00
# Epoch 22/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0918 - accuracy: 0.0000e+00
# Epoch 23/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0869 - accuracy: 0.0000e+00
# Epoch 24/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0836 - accuracy: 0.0000e+00
# Epoch 25/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0843 - accuracy: 0.0000e+00
# Epoch 26/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0824 - accuracy: 0.0000e+00
# Epoch 27/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0819 - accuracy: 0.0000e+00
# Epoch 28/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0763 - accuracy: 0.0000e+00
# Epoch 29/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0764 - accuracy: 0.0000e+00
# Epoch 30/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0731 - accuracy: 0.0000e+00
# Epoch 31/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0764 - accuracy: 0.0000e+00
# Epoch 32/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0707 - accuracy: 0.0000e+00
# Epoch 33/150
# 588/588 [==============================] - 4s 6ms/step - loss: 0.0717 - accuracy: 0.0000e+00
# Epoch 34/150
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0711 - accuracy: 0.0000e+00
# Epoch 35/150
# 588/588 [==============================] - 4s 6ms/step - loss: 0.0671 - accuracy: 0.0000e+00
# Epoch 36/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0679 - accuracy: 0.0000e+00
# Epoch 37/150
# 588/588 [==============================] - 4s 6ms/step - loss: 0.0641 - accuracy: 0.0000e+00
# Epoch 38/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0685 - accuracy: 0.0000e+00
# Epoch 39/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0670 - accuracy: 0.0000e+00
# Epoch 40/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0604 - accuracy: 0.0000e+00
# Epoch 41/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0635 - accuracy: 0.0000e+00
# Epoch 42/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0653 - accuracy: 0.0000e+00
# Epoch 43/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0657 - accuracy: 0.0000e+00
# Epoch 44/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0590 - accuracy: 0.0000e+00
# Epoch 45/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0564 - accuracy: 0.0000e+00
# Epoch 46/150
# 588/588 [==============================] - 3s 6ms/step - loss: 0.0626 - accuracy: 0.0000e+00
# Epoch 47/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0552 - accuracy: 0.0000e+00
# Epoch 48/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0540 - accuracy: 0.0000e+00
# Epoch 49/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0606 - accuracy: 0.0000e+00
# Epoch 50/150
# 588/588 [==============================] - 4s 6ms/step - loss: 0.0522 - accuracy: 0.0000e+00
# Epoch 51/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0557 - accuracy: 0.0000e+00
# Epoch 52/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0538 - accuracy: 0.0000e+00
# Epoch 53/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0543 - accuracy: 0.0000e+00
# Epoch 54/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0552 - accuracy: 0.0000e+00
# Epoch 55/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0522 - accuracy: 0.0000e+00
# Epoch 56/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0528 - accuracy: 0.0000e+00
# Epoch 57/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0530 - accuracy: 0.0000e+00
# Epoch 58/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0544 - accuracy: 0.0000e+00
# Epoch 59/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0491 - accuracy: 0.0000e+00
# Epoch 60/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0529 - accuracy: 0.0000e+00
# Epoch 61/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0475 - accuracy: 0.0000e+00
# Epoch 62/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0498 - accuracy: 0.0000e+00
# Epoch 63/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0523 - accuracy: 0.0000e+00
# Epoch 64/150
# 588/588 [==============================] - 3s 6ms/step - loss: 0.0455 - accuracy: 0.0000e+00
# Epoch 65/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0502 - accuracy: 0.0000e+00
# Epoch 66/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0505 - accuracy: 0.0000e+00
# Epoch 67/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0500 - accuracy: 0.0000e+00
# Epoch 68/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0460 - accuracy: 0.0000e+00
# Epoch 69/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0478 - accuracy: 0.0000e+00
# Epoch 70/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0421 - accuracy: 0.0000e+00
# Epoch 71/150
# 588/588 [==============================] - 4s 6ms/step - loss: 0.0501 - accuracy: 0.0000e+00
# Epoch 72/150
# 588/588 [==============================] - 4s 6ms/step - loss: 0.0529 - accuracy: 0.0000e+00
# Epoch 73/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0451 - accuracy: 0.0000e+00
# Epoch 74/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0476 - accuracy: 0.0000e+00
# Epoch 75/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0439 - accuracy: 0.0000e+00
# Epoch 76/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0409 - accuracy: 0.0000e+00
# Epoch 77/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0446 - accuracy: 0.0000e+00
# Epoch 78/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0465 - accuracy: 0.0000e+00
# Epoch 79/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0419 - accuracy: 0.0000e+00
# Epoch 80/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0443 - accuracy: 0.0000e+00
# Epoch 81/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0465 - accuracy: 0.0000e+00
# Epoch 82/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0430 - accuracy: 0.0000e+00
# Epoch 83/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0438 - accuracy: 0.0000e+00
# Epoch 84/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0435 - accuracy: 0.0000e+00
# Epoch 85/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0409 - accuracy: 0.0000e+00
# Epoch 86/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0389 - accuracy: 0.0000e+00
# Epoch 87/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0396 - accuracy: 0.0000e+00
# Epoch 88/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0392 - accuracy: 0.0000e+00
# Epoch 89/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0385 - accuracy: 0.0000e+00
# Epoch 90/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0382 - accuracy: 0.0000e+00
# Epoch 91/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0452 - accuracy: 0.0000e+00
# Epoch 92/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0419 - accuracy: 0.0000e+00
# Epoch 93/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0410 - accuracy: 0.0000e+00
# Epoch 94/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0390 - accuracy: 0.0000e+00
# Epoch 95/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0405 - accuracy: 0.0000e+00
# Epoch 96/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0378 - accuracy: 0.0000e+00
# Epoch 97/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0424 - accuracy: 0.0000e+00
# Epoch 98/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0405 - accuracy: 0.0000e+00
# Epoch 99/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0394 - accuracy: 0.0000e+00
# Epoch 100/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0357 - accuracy: 0.0000e+00
# Epoch 101/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0394 - accuracy: 0.0000e+00
# Epoch 102/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0430 - accuracy: 0.0000e+00
# Epoch 103/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0386 - accuracy: 0.0000e+00
# Epoch 104/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0433 - accuracy: 0.0000e+00
# Epoch 105/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0407 - accuracy: 0.0000e+00
# Epoch 106/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0392 - accuracy: 0.0000e+00
# Epoch 107/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0362 - accuracy: 0.0000e+00
# Epoch 108/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0359 - accuracy: 0.0000e+00
# Epoch 109/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0375 - accuracy: 0.0000e+00
# Epoch 110/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0354 - accuracy: 0.0000e+00
# Epoch 111/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0350 - accuracy: 0.0000e+00
# Epoch 112/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0353 - accuracy: 0.0000e+00
# Epoch 113/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0333 - accuracy: 0.0000e+00
# Epoch 114/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0343 - accuracy: 0.0000e+00
# Epoch 115/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0395 - accuracy: 0.0000e+00
# Epoch 116/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0379 - accuracy: 0.0000e+00
# Epoch 117/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0359 - accuracy: 0.0000e+00
# Epoch 118/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0365 - accuracy: 0.0000e+00
# Epoch 119/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0372 - accuracy: 0.0000e+00
# Epoch 120/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0381 - accuracy: 0.0000e+00
# Epoch 121/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0369 - accuracy: 0.0000e+00
# Epoch 122/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0358 - accuracy: 0.0000e+00
# Epoch 123/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0392 - accuracy: 0.0000e+00
# Epoch 124/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0365 - accuracy: 0.0000e+00
# Epoch 125/150
# 588/588 [==============================] - 4s 6ms/step - loss: 0.0344 - accuracy: 0.0000e+00
# Epoch 126/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0397 - accuracy: 0.0000e+00
# Epoch 127/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0354 - accuracy: 0.0000e+00
# Epoch 128/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0342 - accuracy: 0.0000e+00
# Epoch 129/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0377 - accuracy: 0.0000e+00
# Epoch 130/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0330 - accuracy: 0.0000e+00
# Epoch 131/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0388 - accuracy: 0.0000e+00
# Epoch 132/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0338 - accuracy: 0.0000e+00
# Epoch 133/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0315 - accuracy: 0.0000e+00
# Epoch 134/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0366 - accuracy: 0.0000e+00
# Epoch 135/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0339 - accuracy: 0.0000e+00
# Epoch 136/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0361 - accuracy: 0.0000e+00
# Epoch 137/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0360 - accuracy: 0.0000e+00
# Epoch 138/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0356 - accuracy: 0.0000e+00
# Epoch 139/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0357 - accuracy: 0.0000e+00
# Epoch 140/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0339 - accuracy: 0.0000e+00
# Epoch 141/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0325 - accuracy: 0.0000e+00
# Epoch 142/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0287 - accuracy: 0.0000e+00
# Epoch 143/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0394 - accuracy: 0.0000e+00
# Epoch 144/150
# 588/588 [==============================] - 3s 5ms/step - loss: 0.0356 - accuracy: 0.0000e+00
# Epoch 145/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0327 - accuracy: 0.0000e+00
# Epoch 146/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0318 - accuracy: 0.0000e+00
# Epoch 147/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0318 - accuracy: 0.0000e+00
# Epoch 148/150
# 588/588 [==============================] - 3s 4ms/step - loss: 0.0312 - accuracy: 0.0000e+00
# Epoch 149/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0312 - accuracy: 0.0000e+00
# Epoch 150/150
# 588/588 [==============================] - 2s 4ms/step - loss: 0.0311 - accuracy: 0.0000e+00

# %%
predict_gama = model.predict(x_test)
model.save('model.h5')

# %% [markdown]
# # Eval

# %%
from keras.metrics import Precision
from matplotlib.colors import hsv_to_rgb
# Eval
ERROR = []
for i in range(len(predict_gama)):
  # original 
  hsv_origi = np.copy(HSV_TEST[i])
  RGB_ORIGI = hsv_to_rgb(hsv_origi)

  #Edit
  hsv_edit = np.copy(HSV_TEST[i])
  v = x_test[i]
  v = v.reshape((128,128))
  hsv_edit[:,:,2] = v
  RGB_EDIT = hsv_to_rgb(hsv_edit)

  # inferencia 
  hsv_pred = np.copy(HSV_TEST[i])
  VV = x_test[i]
  VV = VV.reshape((128,128))
  hsv_pred[:,:,2] = VV / predict_gama[i]
  RGB_PREDICT = hsv_to_rgb(hsv_pred)

  # Diferencia
  RGB_DIFF = RGB_ORIGI - RGB_PREDICT

  mean_diference = abs(np.mean(RGB_DIFF))
  mean_original = abs(np.mean(RGB_ORIGI))
  error_img = mean_diference / mean_original 
  ERROR.append(error_img)
  #print(error_img)
print('___________________________________')
print('___________________________________')
precision_model = 1 - abs(np.mean(ERROR))
print('model presicion: ', round(precision_model,3) )
# Out:
# ___________________________________
# ___________________________________
# model presicion:  0.626

# %%
from keras.metrics import Precision
# Show examples
for i in range(10):
  print('___________________________________________________________________________________')
  # original 
  hsv_origi = np.copy(HSV_TEST[i])
  RGB_ORIGI = hsv_to_rgb(hsv_origi)
  plt.imshow(RGB_ORIGI)
  plt.show()

  #Edit
  hsv_edit = np.copy(HSV_TEST[i])
  v = x_test[i]
  v = v.reshape((128,128))
  hsv_edit[:,:,2] = v
  RGB_EDIT = hsv_to_rgb(hsv_edit)
  plt.imshow(RGB_EDIT)
  plt.show()

  # inferencia 
  hsv_pred = np.copy(HSV_TEST[i])
  VV = x_test[i]
  VV = VV.reshape((128,128))
  hsv_pred[:,:,2] = VV / predict_gama[i]
  RGB_PREDICT = hsv_to_rgb(hsv_pred)
  plt.imshow(RGB_PREDICT)
  plt.show()

  # Diferencia
  RGB_DIFF = RGB_ORIGI - RGB_PREDICT
  plt.imshow(RGB_DIFF)
  plt.show()
# Out:
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ___________________________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
